# %%
import re
import os
from collections import defaultdict
from pdfminer.high_level import extract_text
from nltk.tokenize import RegexpTokenizer
import collections
import matplotlib.pyplot as plt
import math
from math import sqrt
amharic_punc_and_apos = r"[፨፧፦!፥፤፣፣።፡,():;.\'\u1369-\u137C]+"
amharic_punc_and_apos_pattern = re.compile(amharic_punc_and_apos)
amharic_pattern = re.compile(r"[\u1200-\u137F]+")


def Normalize_tokenize(text):
    clean_text = amharic_punc_and_apos_pattern.sub(' ', text)
    tokenized = amharic_pattern.findall(clean_text)
    newtext=[]
    for words in tokenized:
        rep1=re.sub('[ሃኀኃሐሓኻ]','ሀ' ,words)
        rep2=re.sub('[ሑኁዅ]','ሁ',rep1)
        rep3=re.sub('[ኂሒኺ]','ሂ',rep2)
        rep4=re.sub('[ኌሔዄ]','ሄ',rep3)
        rep5=re.sub('[ሕኅ]','ህ',rep4)
        rep6=re.sub('[ኆሖኾ]','ሆ',rep5)
        rep7=re.sub('[ሠ]','ሰ',rep6)
        rep8=re.sub('[ሡ]','ሱ',rep7)
        rep9=re.sub('[ሢ]','ሲ',rep8)
        rep10=re.sub('[ሣ]','ሳ',rep9)
        rep11=re.sub('[ሤ]','ሴ',rep10)
        rep12=re.sub('[ሥ]','ስ',rep11)
        rep13=re.sub('[ሦ]','ሶ',rep12)
        rep14=re.sub('[ዓኣዐ]','አ',rep13)
        rep15=re.sub('[ዑ]','ኡ',rep14)
        rep16=re.sub('[ዒ]','ኢ',rep15)
        rep17=re.sub('[ዔ]','ኤ',rep16)
        rep18=re.sub('[ዕ]','እ',rep17)
        rep19=re.sub('[ዖ]','ኦ',rep18)
        rep20=re.sub('[ጸ]','ፀ',rep19)
        rep21=re.sub('[ጹ]','ፁ',rep20)
        rep22=re.sub('[ጺ]','ፂ',rep21)
        rep23=re.sub('[ጻ]','ፃ',rep22)
        rep24=re.sub('[ጼ]','ፄ',rep23)
        rep25=re.sub('[ጽ]','ፅ',rep24)
        rep26=re.sub('[ጾ]','ፆ',rep25)     
        rep27=re.sub('(ሉ[ዋአ])','ሏ',rep26)
        rep28=re.sub('(ሙ[ዋአ])','ሟ',rep27)
        rep29=re.sub('(ቱ[ዋአ])','ቷ',rep28)
        rep30=re.sub('(ሩ[ዋአ])','ሯ',rep29)
        rep31=re.sub('(ሱ[ዋአ])','ሷ',rep30)
        rep32=re.sub('(ሹ[ዋአ])','ሿ',rep31)
        rep33=re.sub('(ቁ[ዋአ])','ቋ',rep32)
        rep34=re.sub('(ቡ[ዋአ])','ቧ',rep33)
        rep35=re.sub('(ቹ[ዋአ])','ቿ',rep34)
        rep36=re.sub('(ሁ[ዋአ])','ኋ',rep35)
        rep37=re.sub('(ኑ[ዋአ])','ኗ',rep36)
        rep38=re.sub('(ኙ[ዋአ])','ኟ',rep37)
        rep39=re.sub('(ኩ[ዋአ])','ኳ',rep38)
        rep40=re.sub('(ዙ[ዋአ])','ዟ',rep39)
        rep41=re.sub('(ጉ[ዋአ])','ጓ',rep40)
        rep42=re.sub('(ደ[ዋአ])','ዷ',rep41)
        rep43=re.sub('(ጡ[ዋአ])','ጧ',rep42)
        rep44=re.sub('(ጩ[ዋአ])','ጯ',rep43)
        rep45=re.sub('(ጹ[ዋአ])','ጿ',rep44)
        rep46=re.sub('(ፉ[ዋአ])','ፏ',rep45)
        rep47=re.sub('[ቊ]','ቁ',rep46) #ቁ can be written as ቊ
        rep48=re.sub('[ኵ]','ኩ',rep47)#ኩ can be also written as ኵ  
        newtext.append(rep48)
    return newtext
def stop_word_remover(text,stopwords):
    new_text=[word for word in text if word not in stopwords]
    return new_text

with open("tokenized.txt", "r", encoding="utf-8") as tokenized:
    tokens = tokenized.read() 
index=Normalize_tokenize(tokens)
print(index)
with open("index.txt", "w", encoding="utf-8") as tobeinverted:
    for words in index:
        tobeinverted.write(words+" ")



#run time ==
# Out:
# ['እንደመጀመሪያ', 'መፅሀፍ', 'አዘጋጆች', 'አፀደማርያም', 'ሲሻው', 'ወግደረሰኝ', 'ዳንኤል', 'ገላነው', 'ጉድብ', 'ካሳ', 'ገምጋሚና', 'አርታኢ', 'መስፍን', 'ደፈረሱ', 'ወልደመድህን', 'ትንቢት', 'ሀይሉ', 'ብዙነህ', 'በቀለ', 'ጥራት', 'ተቆጣጣሪና', 'ገምጋሚ', 'ፍሬህይወት', 'አሰፋ', 'ከበደ', 'አስተባባሪ', 'ጌታቸው', 'ታለማ', 'አጥናፉ', 'አቀማመጥ', 'እንጦጦ', 'ፖሊ', 'ቴክኒክ', 'የመፅሀፉ', 'ህጋዊ', 'ቅጂ', 'ከዝግጅት', 'በከተማችን', 'በሚያስተምሩ', 'እንዲዘጋጅ', 'አስፈላጊውን', 'በማስፈቀድ', 'ዲስፕሊን', 'እንዲመራ', 'ሙያዊና', 'አስተዳደራዊ', 'ዘላለም', 'ሙላቱ', 'የዝግጅቱ', 'ተረድተው', 'በሚያጋጥሙ', 'የአፈፃፀም', 'ሂደቱን', 'በመከታተል', 'በመገምገም', 'ከጎናችን', 'ለነበሩ', 'የማኔጅመንት', 'አድማሱ', 'ደቻሳ', 'ቴክኖሎጂ', 'ዳኛው', 'ገብሩ', 'የመምህራን', 'ሳምሶን', 'አበበች', 'ነጋሽ', 'ሲሳይ', 'እንዳለ', 'ለቴክኒክ', 'መርሻ', 'ላበረከቱት', 'አስተዋፅኦ', 'ይገባቸዋል', 'መፅሀፉ', 'ተጀምሮ', 'እስኪጠናቀቅ', 'ለአዘጋጅ', 'ፍቃድ', 'በመስጠትና', 'የሞራል', 'ስላደረጋችሁም', 'ምስጋናችን', 'ማውጫ', 'እፆች', 'አባሪ', 'አማርኛን', 'ቋንቋነት', 'ክፍልተማሪዎች', 'በቋንቋዉ', 'በብቃት', 'ማንበብና', 'መፃፍእንዲችሉ', 'ለማድረግ', 'የስርአተ', 'በተጨማሪምመፅሀፉ', 'ትምህርትና', 'ለሚሰጠው', 'የትምህርትሽፋን', 'ተማሪዎችና', 'ቤትየተከናወኑ', 'ተግባራትን', 'ለማስቀጠልና', 'ለመስራትያስችላቸዋል', 'ህይወት', 'የማዳመጥይዘቶችና', 'ለእነዚህ', 'ምንባቦችንካዳመጡ', 'ይናገራሉ', 'በቀጣይም', 'ስለእነዚህ', 'ይዘቶች', 'ካነበቡ', 'ይፅፋሉ', 'በተቀመጠው', 'ከተማሩ', 'ሶስትና', 'ትምህርቶችን', 'በየምእራፉ', 'የቃላትና', 'በተገለፀው', 'መሰረትይማራሉ', 'አብረዋቸው', 'ከሚማሩ', 'ከቤተሰብ', 'የሚቀስሟቸውና', 'በቤታቸው', 'ከወላጆቻ